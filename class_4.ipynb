# %% [markdown]
# # Class 4 - Stack and Queuse
#
# ## Stacks
# A stack is an ordered collection of elements where items are added and removed from one end, commonly referred to as the "top". The ordering princing is referred to as LIFO (list in, First out)
#
# ## Queuses
# A queue is an ordered collection of elements where items are added and removed from ***opposite*** ends, commonly referred to as the "front" and "back" or "rear" of the queue. The ordering principle is referred to as FIFO (first in, first out) or "first come first served".

# %%
class Stack:
  def __init__(self):
    self.items = []

  def push(self, value):
    self.items.append(value)

  def pop(self):
    return self.items.pop()
  
  def size(self):
    return len(self.itmes)
  
  def peek(self):
    return self.items[len(self.items)--1]
  
  def is_empty(self):
    return self.items == []
  
stack = Stack()
stack.push(30)
stack.push(33)
stack.push(25)
print (stack.peek())
print (stack.pop())
print (stack.items)
stack.size()
stack.is_empty()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[20], line 24
#      22 stack.push(33)
#      23 stack.push(25)
# ---> 24 print (stack.peek())
#      25 print (stack.pop())
#      26 print (stack.items)
#
# Cell In[20], line 15, in Stack.peek(self)
#      14 def peek(self):
# ---> 15   return self.items[len(self.items)--1]
#
# IndexError: list index out of range

# %%
class Queue:
  def __init__(self):
    self.items = []

  def equeue(self, element):
    self.items.instert(0, element)

  def dequeue(self):
    return self.item.pop()
  
  def peek(self):
    return self.items[len(self.items)-1]
  
  def size(self):
    return len(self.items)
  
  def is_empty(self):
    return self.items == []
  

class_queue = Queue()
class_queue.enqueue("Kelendria")
class_queue.enqueue("Beyonce")
class_queue.equeue("Michelle")
class_queue.equeue("Tatiana")
print(class_queue.items)

# %%
# Stack class = Cstack

class Node:
  def __init__(self, data):
    self.data = data
    self.below = None

class Cstack:
  def __init__(self):
    self.top = None

  
  def push(self, value):
    if not self.top:
      self.top = Node(value)

    else:
      new_node = Node(value)
      new_node.below = self.top
      self.top = new_node


  def pop(self):
    if not self.top:
      raise IndexError("Stack is Empty")
    
    else:
      current = self.top.data
      self.top = self.top.below
      return current
    
  def is_empty(self):
      return self.top == None
  

custom_stack = "CustomStack"()
custom_stack.push(60)
custom_stack.push(70)
custom_stack.push(20)
custom_stack.pop()
custom_stack.pop()
custom_stack.pop()
custom_stack.pop()
